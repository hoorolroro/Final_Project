# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/SAMSUNG/NLP_TRY(Final project)/after_최종본/입체형_뉴네퓨어_kf94_대형_after2.csv')

# %%
df['review_content\r'][0]
# Out:
# '항상 구입하는 마스크여서 끈조절이 되서 아이들이 편하게 쓰고 있습니다!배송도 빠르고 좋아요~\r'

# %% [markdown]
# 함수로 만들어준다

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")

# %%
word = m.morphs(df['review_content\r'][6])

# %%
word
# Out:
# ['남편',
#  '이',
#  '애용',
#  '하',
#  '는',
#  '마스크',
#  '예요',
#  '~',
#  '차단',
#  '율',
#  '도',
#  '좋',
#  '고',
#  '끈',
#  '조절',
#  '기능',
#  '도',
#  '있',
#  '어서',
#  '딸',
#  '도',
#  '좋',
#  '아',
#  '하',
#  '네요',
#  '~~',
#  '떨어질',
#  '때',
#  '마다',
#  '구입',
#  '해요',
#  '~']

# %%
import json

class KnuSL():
    
    def data_list(wordname):
        with open('C:/Users/SAMSUNG/NLP_TRY(Final project)/SentiWord_info(2차 수정본).json', encoding='utf-8-sig', mode='r') as f:
            data = json.load(f)
        result = ['','']
#         pos = 0
#         neg = 0
        for i in range(0, len(data)):
            if data[i]['word_root'] == wordname:
                result.pop()
                result.pop()
                result.append(data[i]['word'])
                result.append(data[i]['polarity'])
#             if result[1] == 1:
#                 pos += 1
#             elif result[1] == - 1:
#                 neg += 1
        r_word = result[0]
        s_word = result[1]

        print('단어 : ', wordname)
        print('어근 : ' + r_word)
        print('극성 : ', s_word)
        # fomula = (긍정어 수 - 부정어 수) / (긍정어 수 + 부정어 수)
        

        return r_word, s_word

if __name__ == "__main__":

    ksl = KnuSL

    
    print(df['review_content\r'][0])
    print(word)
    print("-1:부정, 0:중립 or Unkwon, 1:긍정")
    print("\n")	

    for i in range(len(word)):
        wordname = word[i]
        wordname = wordname.strip(" ")
        if wordname != "#":
            print(ksl.data_list(wordname))
            print("\n")	


        elif wordname == "#":
            print("\n이용해주셔서 감사합니다~ :)")

#     print('감성지수 :', fomula, '점')
# Out:
# 항상 구입하는 마스크여서 끈조절이 되서 아이들이 편하게 쓰고 있습니다!배송도 빠르고 좋아요~
# ['남편', '이', '애용', '하', '는', '마스크', '예요', '~', '차단', '율', '도', '좋', '고', '끈', '조절', '기능', '도', '있', '어서', '딸', '도', '좋', '아', '하', '네요', '~~', '떨어질', '때', '마다', '구입', '해요', '~']
# -1:부정, 0:중립 or Unkwon, 1:긍정
#
#
# 단어 :  남편
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  이
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  애용
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  하
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  는
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  마스크
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  예요
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  ~
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  차단
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  율
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  도
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  좋
# 어근 : 좋다
# 극성 :  1
# ('좋다', 1)
#
#
# 단어 :  고
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  끈
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  조절
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  기능
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  도
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  있
# 어근 : 있다
# 극성 :  1
# ('있다', 1)
#
#
# 단어 :  어서
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  딸
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  도
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  좋
# 어근 : 좋다
# 극성 :  1
# ('좋다', 1)
#
#
# 단어 :  아
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  하
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  네요
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  ~~
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  떨어질
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  때
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  마다
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  구입
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  해요
# 어근 :
# 극성 :
# ('', '')
#
#
# 단어 :  ~
# 어근 :
# 극성 :
# ('', '')

# %%
#         fomula = ((pos - neg) / (pos + neg)) * 100
